# %% [markdown]
# Install efficientnet for pytorch

# %%
# !pip install efficientnet-pytorch
# Out:
# Requirement already satisfied: efficientnet-pytorch in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch) (1.3.0)

# %% [markdown]
# Import required libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import pandas as pd
import shutil
import random
import torch.nn.functional as F
from torch.utils.data.sampler import WeightedRandomSampler
import time
from datetime import datetime
import copy
from efficientnet_pytorch import EfficientNet
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from torchvision.models._api import WeightsEnum
from torch.hub import load_state_dict_from_url

# use best algorithm for hardware
cudnn.benchmark = True

# interactive mode for graph plot
plt.ion()

# %% [markdown]
# Extract data

# %%
#copy data zip from drive
from google.colab import drive
drive.mount('/content/drive')
# !cp drive/MyDrive/uni/Honours/ISIC_2019.zip ./ISIC_2019.zip

#unzip dataset
# !unzip -x -q ISIC_2019.zip

#remove zip file
# !rm ISIC_2019.zip
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# replace ISIC_2019_Resized/ISIC_0000000.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Sort data into folders based on class

# %%
# function to sort the images into class folders based on given csv file
def copy_images_to_folders(csv_path, image_folder, output_folder):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(csv_path)

    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        image_name = row['image'] + '.jpg'  # Assuming images have '.jpg' extension
        image_path = os.path.join(image_folder, image_name)

        # Iterate through class columns and copy images to the corresponding folders
        for class_name in df.columns[1:]:
            class_folder = os.path.join(output_folder, class_name)
            os.makedirs(class_folder, exist_ok=True)  # Create folder if it doesn't exist

            if row[class_name] == 1:  # Check if the image belongs to the class
                shutil.copy(image_path, class_folder)

csv_path = '/content/ISIC_2019_Training_GroundTruth.csv'
image_folder = '/content/ISIC_2019_Resized'
output_folder = '/content/ISIC_Sorted'

copy_images_to_folders(csv_path, image_folder, output_folder)

# %% [markdown]
# Select random subset of data from every class for training and validation

# %%
# declare variables for model creation
input_folder = '/content/ISIC_Sorted'  # This is the folder containing class subdirectories
output_folder = '/content/data_subset'  # The desired output folder for "training" and "validation" folders
#data_dir = '/content/data_subset'
num_samples=10000
validation_ratio=0.2
set_batch_size=32

#sample numbers by class copied here for reference
#MEL	NV	  BCC	  AK	BKL	  DF	VASC	SCC	UNK
#4522	12875	3323	867	2624	239	253	  628	0

'''
Melanoma (MEL)
Melanocytic nevus (NV)
Basal cell carcinoma (BCC)
Actinic keratosis (AK)
Benign keratosis (BKL) [solar lentigo / seborrheic keratosis / lichen planus-like keratosis]
Dermatofibroma (DF)
Vascular lesion (VASC)
Squamous cell carcinoma (SCC)
None of the others (UNK)
'''

# %%
# Remove existing "training" and "validation" folders if they exist
training_folder = os.path.join(output_folder, 'train')
validation_folder = os.path.join(output_folder, 'val')
shutil.rmtree(training_folder, ignore_errors=True)
shutil.rmtree(validation_folder, ignore_errors=True)

# Create the "training" and "validation" folders
os.makedirs(training_folder, exist_ok=True)
os.makedirs(validation_folder, exist_ok=True)

# generate list of class names from the folder structure
class_names = [class_name for class_name in os.listdir(input_folder) if os.path.isdir(os.path.join(input_folder, class_name))]

# %%
# Iterate through each class folder
for class_name in os.listdir(input_folder):
    class_folder_input = os.path.join(input_folder, class_name)
    if os.path.isdir(class_folder_input):
        # Get a list of all images in the class folder
        images = [img for img in os.listdir(class_folder_input) if img.endswith('.jpg')]

        # Randomly shuffle the list of images
        random.shuffle(images)

        #calculate size of class
        class_size = len(os.listdir(os.path.join(input_folder, class_name)))

        # Calculate the number of samples for training and validation
        num_training_samples = int(class_size * (1 - validation_ratio))
        #num_validation_samples = class_size - num_training_samples

        # Create the class subfolders within the "training" and "validation" folders
        class_folder_training = os.path.join(training_folder, class_name)
        class_folder_validation = os.path.join(validation_folder, class_name)
        os.makedirs(class_folder_training, exist_ok=True)
        os.makedirs(class_folder_validation, exist_ok=True)

        # Copy images to the "training" folder
        for image_name in images[:num_training_samples]:
            image_path = os.path.join(class_folder_input, image_name)
            shutil.copy(image_path, class_folder_training)

        # Copy images to the "validation" folder
        for image_name in images[num_training_samples:class_size]:
            image_path = os.path.join(class_folder_input, image_name)
            shutil.copy(image_path, class_folder_validation)

# %%
#remove unknown folder as no samples
shutil.rmtree("/content/data_subset/train/UNK", ignore_errors=True)
shutil.rmtree("/content/data_subset/val/UNK", ignore_errors=True)

# %%
#transform data
data_transforms = {
'train': transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
]),
'val': transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
]),
}

# %%
# create datasets and dataloaders
image_datasets = {x: datasets.ImageFolder(os.path.join(output_folder, x), data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=set_batch_size, shuffle=True, num_workers=2) for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

#print checks to see if the values are the same - if yes then can remove the assignment here
print(f"file: ", class_names)
class_names = image_datasets['train'].classes
print(f"file: ", class_names)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# get the sample size for each class
class_sizes = [len(os.listdir(os.path.join(training_folder, class_name))) for class_name in class_names]

# get the max sample size across classes
max_class_size = max(class_sizes)

# Calculate the desired repetitions for each class
# this is the number of times a sample needs to be repeated to match the max class size
desired_repetitions = [max_class_size // class_size if class_size > 0 else 1 for class_size in class_sizes]

# Iterate through each class and oversample accordingly
for class_index, class_name in enumerate(class_names):
    #get the training folder for the current class
    class_folder_training = os.path.join(training_folder, class_name)
    class_indices = [i for i, label in enumerate(image_datasets['train'].targets) if label == class_index]

    weights = [1.0 if label != class_index else desired_repetitions[class_index] for label in image_datasets['train'].targets]
    sampler = WeightedRandomSampler(weights, len(weights), replacement=True)

    # Update the data loader for the "training" set with the weighted sampler
    dataloaders['train'] = torch.utils.data.DataLoader(image_datasets['train'], batch_size=set_batch_size, sampler=sampler, num_workers=2)

# %% [markdown]
# oversample validation set for testing

# %%
# Duplicate validation dataset
image_datasets['val_oversampled'] = copy.deepcopy(image_datasets['val'])

# Create a dataloader for the oversampled validation dataset
val_oversampled_dataloader = torch.utils.data.DataLoader(image_datasets['val_oversampled'], batch_size=set_batch_size, shuffle=False, num_workers=2)

# Oversample the validation dataset
val_desired_repetitions = [max_class_size // class_size if class_size > 0 else 1 for class_size in class_sizes]

for class_index, class_name in enumerate(class_names):
    val_class_folder = os.path.join(output_folder, 'val', class_name)
    val_class_indices = [i for i, label in enumerate(image_datasets['val_oversampled'].targets) if label == class_index]

    val_weights = [1.0 if label != class_index else val_desired_repetitions[class_index] for label in image_datasets['val_oversampled'].targets]
    val_sampler = WeightedRandomSampler(val_weights, len(val_weights), replacement=True)

    # Update the sampler for the existing dataloader
    val_oversampled_dataloader = torch.utils.data.DataLoader(image_datasets['val_oversampled'], batch_size=set_batch_size, sampler=val_sampler, num_workers=2)

# Calculate the size of the oversampled validation dataset and add it to dataset_sizes
dataset_sizes['val_oversampled'] = len(image_datasets['val_oversampled'])

# Assign the final oversampled dataloader to the dictionary
dataloaders['val_oversampled'] = val_oversampled_dataloader

# %% [markdown]
# show sample images

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# model training function

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')
        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            print(f'Epoch {epoch}/{num_epochs - 1} - {current_time}')
            print('-' * 10)

            for phase in ['train', 'val', 'val_oversampled']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()

                running_loss = 0.0
                running_corrects = 0

                data_loader = dataloaders[phase]

                for inputs, labels in data_loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    optimizer.zero_grad()

                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                if phase == 'train':
                    print(f'Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}')
                elif phase == 'val':
                    print(f'Val Loss: {epoch_loss:.4f}, Val Acc: {epoch_acc:.4f}')
                elif phase == 'val_oversampled':
                    print(f'Over Val Loss: {epoch_loss:.4f}, Over Val Acc: {epoch_acc:.4f}')

                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:.4f}')

        model.load_state_dict(torch.load(best_model_params_path))

    return model

# %% [markdown]
# temporary fix for efficientnet weights issue

# %%
def get_state_dict(self, *args, **kwargs):
    kwargs.pop("check_hash")
    return load_state_dict_from_url(self.url, *args, **kwargs)
WeightsEnum.get_state_dict = get_state_dict

# %% [markdown]
# model fitting configuration

# %%
model_ft = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
num_ftrs = model_ft.classifier[-1].in_features
model_ft.fc = nn.Linear(num_ftrs, len(class_names))

# %% [markdown]
# MC dropout test

# %%
class CustomEfficientNetB0(nn.Module):
    def __init__(self, num_classes=1, dropout_prob=0.5):
        super(CustomEfficientNetB0, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=num_classes, pretrained=True)
        num_ftrs = self.model._fc.in_features
        self.model._fc = nn.Sequential(
            nn.Dropout(dropout_prob),
            nn.Linear(num_ftrs, num_classes)
        )

    def forward(self, x):
        x = self.model(x)
        return x

# Initialize the model with dropout
model_ft = CustomEfficientNetB0(num_classes=len(class_names), dropout_prob=0.5)

# %%
class CustomEfficientNetB0(nn.Module):
    def __init__(self, num_classes=1, dropout_prob=0.5):
        super(CustomEfficientNetB0, self).__init__()
        self.model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=num_classes)

        # Iterate over all modules in the model
        for module in self.model.children():
            if isinstance(module, nn.Linear):
                # If the module is a fully connected layer, add dropout
                module.add_module('dropout', nn.Dropout(dropout_prob))

    def forward(self, x):
        x = self.model(x)
        return x

# Initialize the model with dropout
model_ft = CustomEfficientNetB0(num_classes=len(class_names), dropout_prob=0.5)

# %%
model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# train model

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24 - 2024-01-30 16:17:22
# ----------
# Train Loss: 1.0815, Train Acc: 0.6406
# Val Loss: 1.0865, Val Acc: 0.6307
# Over Val Loss: 0.8292, Over Val Acc: 0.7207
#
# Epoch 1/24 - 2024-01-30 16:20:19
# ----------
# Train Loss: 0.7914, Train Acc: 0.7262
# Val Loss: 0.9805, Val Acc: 0.6589
# Over Val Loss: 0.7038, Over Val Acc: 0.7643
#
# Epoch 2/24 - 2024-01-30 16:23:14
# ----------
# Train Loss: 0.7365, Train Acc: 0.7440
# Val Loss: 0.9023, Val Acc: 0.6865
# Over Val Loss: 0.6709, Over Val Acc: 0.7798
#
# Epoch 3/24 - 2024-01-30 16:26:10
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-f9ac946d16ce> in <cell line: 1>()
# ----> 1 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
#
# <ipython-input-14-b1196203b0c1> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      38                             optimizer.step()
#      39
# ---> 40                     running_loss += loss.item() * inputs.size(0)
#      41                     running_corrects += torch.sum(preds == labels.data)
#      42
#
# KeyboardInterrupt:

# %% [markdown]
# visualise trained model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images // 2, 2, images_so_far)
                ax.axis('off')

                predicted_class = class_names[preds[j]]
                actual_class = class_names[labels[j]]
                title = f'Predicted: {predicted_class}\nActual: {actual_class}'
                ax.set_title(title)

                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft, num_images=10)

# %% [markdown]
# method for calculating uncertainties

# %%
def calculate_uncertainties(model, dataloader, uncertainty_func, class_names, device, use_mc_dropout=False, num_samples=10):
    guesses_are_correct = []
    uncertainties = []

    was_training = model.training
    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            if use_mc_dropout:
                model.train()
                mc_outputs = torch.zeros((num_samples,) + model(inputs).shape).to(device)

                for k in range(num_samples):
                    mc_outputs[k] = model(inputs)

                model.eval()
                outputs = mc_outputs.mean(dim=0)
            else:
                outputs = model(inputs)

            _, preds = torch.max(outputs, 1)

            for j in range(len(inputs)):
                try:
                    predicted_class = class_names[preds[j]]
                    actual_class = class_names[labels[j]]
                    guesses_are_correct.append(actual_class == predicted_class)

                    if use_mc_dropout:
                        uncertainty = uncertainty_func(mc_outputs[:, j])
                    else:
                        uncertainty = uncertainty_func(outputs[j])

                    uncertainties.append(uncertainty)
                except IndexError as e:
                    continue

    model.train(mode=was_training)

    return guesses_are_correct, uncertainties

# %%
def calculate_uncertainties(model, dataloader, uncertainty_func, class_names, device, use_mc_dropout=False, num_samples=10):
    guesses_are_correct = []
    uncertainties = []

    was_training = model.training
    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            if use_mc_dropout:
                model.train()
                mc_outputs = torch.zeros((num_samples,) + model(inputs).shape).to(device)

                for k in range(num_samples):
                    mc_outputs[k] = model(inputs)

                model.eval()
                outputs = mc_outputs.mean(dim=0)
            else:
                outputs = model(inputs)

            _, preds = torch.max(outputs, 1)

            for j in range(len(class_names)):
                predicted_class = class_names[preds[j]]
                actual_class = class_names[labels[j]]
                guesses_are_correct.append(actual_class == predicted_class)

                if use_mc_dropout:
                    uncertainty = uncertainty_func(mc_outputs[:, j])
                else:
                    uncertainty = uncertainty_func(outputs[j])

                uncertainties.append(uncertainty)

    model.train(mode=was_training)

    return guesses_are_correct, uncertainties

# %% [markdown]
# method for calculating risks by coverage

# %%
def calculate_risks(guesses_are_correct, uncertainties):
    risks = []

    while uncertainties:
        risk = 1 - (sum(guesses_are_correct) / len(guesses_are_correct))
        risks.append(risk)

        max_uncertainty_index = uncertainties.index(max(uncertainties))
        uncertainties.pop(max_uncertainty_index)
        guesses_are_correct.pop(max_uncertainty_index)

    risks.reverse()

    return risks

# %% [markdown]
# calculate risks against coverage for softmax response

# %%
# For softmax uncertainty
softmax_guesses_are_correct, softmax_uncertainties = calculate_uncertainties(
    model_ft,
    dataloaders['val'],
    lambda x: 1 - torch.max(F.softmax(x, dim=0)).item(),
    class_names,
    device,
    use_mc_dropout=False  # Set use_mc_dropout to False
)

softmax_risks = calculate_risks(softmax_guesses_are_correct, softmax_uncertainties)
# Out:
# Sample 0:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.04208403825759888
# Sample 1:
#    Predicted: VASC, Actual: BKL
#    Uncertainty: 0.2002856731414795
# Sample 2:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.15455442667007446
# Sample 3:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.5070399343967438
# Sample 4:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.20470768213272095
# Sample 5:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.63739213347435
# Sample 6:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.10968989133834839
# Sample 7:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.12834513187408447
# Sample 32:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.020906269550323486
# Sample 33:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.29959118366241455
# Sample 34:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.23343485593795776
# Sample 35:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.3401118516921997
# Sample 36:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.13443243503570557
# Sample 37:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.021310746669769287
# Sample 38:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4810359477996826
# Sample 39:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.4777907729148865
# Sample 64:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.3665502071380615
# Sample 65:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.025411367416381836
# Sample 66:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.11033940315246582
# Sample 67:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.4417516589164734
# Sample 68:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.012649714946746826
# Sample 69:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.465545654296875
# Sample 70:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.5684405863285065
# Sample 71:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.3581807613372803
# Sample 96:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.012162566184997559
# Sample 97:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.43180930614471436
# Sample 98:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.18937355279922485
# Sample 99:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7422018051147461
# Sample 100:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.5696713626384735
# Sample 101:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.3885875940322876
# Sample 102:
#    Predicted: MEL, Actual: BCC
#    Uncertainty: 0.5579949915409088
# Sample 103:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 7.808208465576172e-05
# Sample 128:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.015025436878204346
# Sample 129:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.3604053258895874
# Sample 130:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.6671512126922607
# Sample 131:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.418773889541626
# Sample 132:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.15848344564437866
# Sample 133:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.36620938777923584
# Sample 134:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.456376850605011
# Sample 135:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.5541487336158752
# Sample 160:
#    Predicted: BCC, Actual: BKL
#    Uncertainty: 0.5881602168083191
# Sample 161:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.38712239265441895
# Sample 162:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4079635739326477
# Sample 163:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2588345408439636
# Sample 164:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.6207170188426971
# Sample 165:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.4495413899421692
# Sample 166:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2635853886604309
# Sample 167:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.309395968914032
# Sample 192:
#    Predicted: BKL, Actual: AK
#    Uncertainty: 0.6882787048816681
# Sample 193:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.1819435954093933
# Sample 194:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.36930686235427856
# Sample 195:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.05631154775619507
# Sample 196:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.10201287269592285
# Sample 197:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.02966231107711792
# Sample 198:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6495336294174194
# Sample 199:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.28884357213974
# Sample 224:
#    Predicted: MEL, Actual: AK
#    Uncertainty: 0.6165791749954224
# Sample 225:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.1750008463859558
# Sample 226:
#    Predicted: BCC, Actual: SCC
#    Uncertainty: 0.762706071138382
# Sample 227:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.23634743690490723
# Sample 228:
#    Predicted: BKL, Actual: MEL
#    Uncertainty: 0.7322302162647247
# Sample 229:
#    Predicted: AK, Actual: AK
#    Uncertainty: 0.6475614607334137
# Sample 230:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.07236999273300171
# Sample 231:
#    Predicted: BCC, Actual: SCC
#    Uncertainty: 0.49372774362564087
# Sample 256:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.012507796287536621
# Sample 257:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.5308346450328827
# Sample 258:
#    Predicted: MEL, Actual: BKL
#    Uncertainty: 0.47093045711517334
# Sample 259:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.13050299882888794
# Sample 260:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.27663397789001465
# Sample 261:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.16756105422973633
# Sample 262:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.31077224016189575
# Sample 263:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.252585232257843
# Sample 288:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.019988536834716797
# Sample 289:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.0561976432800293
# Sample 290:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.5046333074569702
# Sample 291:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.003327488899230957
# Sample 292:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.5421383380889893
# Sample 293:
#    Predicted: MEL, Actual: AK
#    Uncertainty: 0.7717747241258621
# Sample 294:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.4037501811981201
# Sample 295:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.7221657335758209
# Sample 320:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.19371157884597778
# Sample 321:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.5401569306850433
# Sample 322:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.0017761588096618652
# Sample 323:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.

#    Predicted: NV, Actual: NV
#    Uncertainty: 0.048445045948028564
# Sample 5058:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7622227072715759
# Sample 5059:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.007851779460906982
# Sample 5060:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.15453678369522095
# Sample 5061:
#    Predicted: BKL, Actual: BCC
#    Uncertainty: 0.702024519443512
# Sample 5062:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.18725639581680298
# Sample 5063:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4531286358833313

# %% [markdown]
# MC dropout

# %%
# For Monte Carlo Dropout with softmax uncertainty
mc_dropout_guesses_are_correct, mc_dropout_uncertainties = calculate_uncertainties(
    model_ft,
    dataloaders['val'],
    lambda x: 1 - torch.max(F.softmax(x, dim=0)).item(),
    class_names,
    device,
    use_mc_dropout=True,
    num_samples=10  # Adjust the number of Monte Carlo samples as needed
)

mc_dropout_risks = calculate_risks(mc_dropout_guesses_are_correct, mc_dropout_uncertainties)
# Out:
# Sample 0:
#    Predicted: BKL, Actual: SCC
#    Uncertainty: 0.8328862488269806
# Sample 1:
#    Predicted: MEL, Actual: BCC
#    Uncertainty: 0.8135150074958801
# Sample 2:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7856507450342178
# Sample 3:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8225113600492477
# Sample 4:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 0.7489317059516907
# Sample 5:
#    Predicted: VASC, Actual: SCC
#    Uncertainty: 0.8149168640375137
# Sample 6:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.6888523697853088
# Sample 7:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.785290464758873
# Sample 32:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.8257929533720016
# Sample 33:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8409708738327026
# Sample 34:
#    Predicted: VASC, Actual: AK
#    Uncertainty: 0.8279556334018707
# Sample 35:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7549928724765778
# Sample 36:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.7969970107078552
# Sample 37:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8195338696241379
# Sample 38:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8210617899894714
# Sample 39:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6243012845516205
# Sample 64:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8010915815830231
# Sample 65:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8187068700790405
# Sample 66:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.821435272693634
# Sample 67:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.814743161201477
# Sample 68:
#    Predicted: MEL, Actual: BKL
#    Uncertainty: 0.8161288946866989
# Sample 69:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.13598352670669556
# Sample 70:
#    Predicted: NV, Actual: BCC
#    Uncertainty: 0.6323823630809784
# Sample 71:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7472889125347137
# Sample 96:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.6384951770305634
# Sample 97:
#    Predicted: NV, Actual: BCC
#    Uncertainty: 0.7207403182983398
# Sample 98:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8051551431417465
# Sample 99:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.6703691184520721
# Sample 100:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.8400242030620575
# Sample 101:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.7379502356052399
# Sample 102:
#    Predicted: BCC, Actual: DF
#    Uncertainty: 0.8335906863212585
# Sample 103:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7889375239610672
# Sample 128:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5964658856391907
# Sample 129:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5738328695297241
# Sample 130:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.8445107340812683
# Sample 131:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.8008736819028854
# Sample 132:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.672408401966095
# Sample 133:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.8211265206336975
# Sample 134:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7514464110136032
# Sample 135:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8138214945793152
# Sample 160:
#    Predicted: BCC, Actual: SCC
#    Uncertainty: 0.8395293951034546
# Sample 161:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8485031425952911
# Sample 162:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7152248620986938
# Sample 163:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.7780926823616028
# Sample 164:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.776612862944603
# Sample 165:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7752985656261444
# Sample 166:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.6416231989860535
# Sample 167:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7659288048744202
# Sample 192:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.7913722991943359
# Sample 193:
#    Predicted: BKL, Actual: SCC
#    Uncertainty: 0.8293363600969315
# Sample 194:
#    Predicted: VASC, Actual: SCC
#    Uncertainty: 0.8049132227897644
# Sample 195:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7549899816513062
# Sample 196:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8567426204681396
# Sample 197:
#    Predicted: AK, Actual: BCC
#    Uncertainty: 0.8159799575805664
# Sample 198:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7142188549041748
# Sample 199:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8062379062175751
# Sample 224:
#    Predicted: NV, Actual: BCC
#    Uncertainty: 0.8325754255056381
# Sample 225:
#    Predicted: BKL, Actual: AK
#    Uncertainty: 0.8482501208782196
# Sample 226:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7946461886167526
# Sample 227:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6832907795906067
# Sample 228:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.7502182871103287
# Sample 229:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.8153267204761505
# Sample 230:
#    Predicted: VASC, Actual: BKL
#    Uncertainty: 0.7421577572822571
# Sample 231:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.7669155448675156
# Sample 256:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8054067045450211
# Sample 257:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.6748656630516052
# Sample 258:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.7445734441280365
# Sample 259:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8205920457839966
# Sample 260:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.795983076095581
# Sample 261:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.7996602952480316
# Sample 262:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.8190480768680573
# Sample 263:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.8317864835262299
# Sample 288:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7993777096271515
# Sample 289:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.6878782510757446
# Sample 290:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.7819314152002335
# Sample 291:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.

#    Predicted: NV, Actual: NV
#    Uncertainty: 0.829322949051857
# Sample 4739:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.770743727684021
# Sample 4740:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8212629407644272
# Sample 4741:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8162747770547867
# Sample 4742:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7258704304695129
# Sample 4743:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6391812562942505
# Sample 4768:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.7587104737758636
# Sample 4769:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.7833875715732574
# Sample 4770:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.8011601269245148
# Sample 4771:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.8080893903970718
# Sample 4772:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8229532092809677
# Sample 4773:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.786581352353096
# Sample 4774:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8200501054525375
# Sample 4775:
#    Predicted: BKL, Actual: MEL
#    Uncertainty: 0.8355208337306976
# Sample 4800:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7976548373699188
# Sample 4801:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8427475839853287
# Sample 4802:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.8161227256059647
# Sample 4803:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.7430725693702698
# Sample 4804:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7630579620599747
# Sample 4805:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.8360116183757782
# Sample 4806:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.6211255788803101
# Sample 4807:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8049133867025375
# Sample 4832:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.7573215663433075
# Sample 4833:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8287412971258163
# Sample 4834:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.8429987579584122
# Sample 4835:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7796925455331802
# Sample 4836:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.808750569820404
# Sample 4837:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8508620262145996
# Sample 4838:
#    Predicted: MEL, Actual: DF
#    Uncertainty: 0.8109831660985947
# Sample 4839:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.7061411738395691
# Sample 4864:
#    Predicted: MEL, Actual: BKL
#    Uncertainty: 0.8323377519845963
# Sample 4865:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7754034847021103
# Sample 4866:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.8469057828187943
# Sample 4867:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6948601603507996
# Sample 4868:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7190438508987427
# Sample 4869:
#    Predicted: BKL, Actual: NV
#    Uncertainty: 0.7646865844726562
# Sample 4870:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8091858774423599
# Sample 4871:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6831872761249542
# Sample 4896:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8347105234861374
# Sample 4897:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7354320585727692
# Sample 4898:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.820207267999649
# Sample 4899:
#    Predicted: NV, Actual: BCC
#    Uncertainty: 0.7754085659980774
# Sample 4900:
#    Predicted: VASC, Actual: DF
#    Uncertainty: 0.8500751107931137
# Sample 4901:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8138683289289474
# Sample 4902:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.73170006275177
# Sample 4903:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.7635110914707184
# Sample 4928:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.3676013946533203
# Sample 4929:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8092008978128433
# Sample 4930:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8102648556232452
# Sample 4931:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.6260309517383575
# Sample 4932:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8357405960559845
# Sample 4933:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8004156649112701
# Sample 4934:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7169893682003021
# Sample 4935:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.8067097365856171
# Sample 4960:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8396425396203995
# Sample 4961:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8608590215444565
# Sample 4962:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.7189039885997772
# Sample 4963:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7641189694404602
# Sample 4964:
#    Predicted: VASC, Actual: AK
#    Uncertainty: 0.8147686123847961
# Sample 4965:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7998905777931213
# Sample 4966:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8081923872232437
# Sample 4967:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.5952870547771454
# Sample 4992:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.8220889121294022
# Sample 4993:
#    Predicted: VASC, Actual: BKL
#    Uncertainty: 0.781463161110878
# Sample 4994:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7485773265361786
# Sample 4995:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7932178527116776
# Sample 4996:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5766465961933136
# Sample 4997:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.783814549446106
# Sample 4998:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.8515340387821198
# Sample 4999:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.7776990830898285
# Sample 5024:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.5304455161094666
# Sample 5025:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8323928862810135
# Sample 5026:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.4661577343940735
# Sample 5027:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.5072428584098816
# Sample 5028:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7272452116012573
# Sample 5029:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7427579164505005
# Sample 5030:
#    Predicted: MEL, Actual: AK
#    Uncertainty: 0.8335647732019424
# Sample 5031:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.8270692974328995
# Sample 5056:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7813241183757782
# Sample 5057:
#    Predicted: MEL, Actual: BCC
#    Uncertainty: 0.8094851672649384
# Sample 5058:
#    Predicted: MEL, Actual: BKL
#    Uncertainty: 0.8495507836341858
# Sample 5059:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7716085463762283
# Sample 5060:
#    Predicted: MEL, Actual: BKL
#    Uncertainty: 0.818748265504837
# Sample 5061:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.7793492078781128
# Sample 5062:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.807942196726799
# Sample 5063:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.4739459753036499

# %% [markdown]
# calculate risks against coverage for random uncertainties

# %%
# For random uncertainty
random_guesses_are_correct, random_uncertainties = calculate_uncertainties(
    model_ft,
    dataloaders['val'],
    lambda x: random.uniform(0, 1),
    class_names,
    device,
    use_mc_dropout=False  # Set use_mc_dropout to False
)

random_risks = calculate_risks(random_guesses_are_correct, random_uncertainties)
# Out:
# Sample 0:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.

#    Predicted: NV, Actual: NV
#    Uncertainty: 0.04857349638672814
# Sample 4352:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.47783443155234384
# Sample 4353:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 0.29851190630819313
# Sample 4354:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.02471236338650895
# Sample 4355:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.05302964934247478
# Sample 4356:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6424360190045834
# Sample 4357:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8458169919097887
# Sample 4358:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.4793417119368978
# Sample 4359:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.008779831656937409
# Sample 4384:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.18157872569048472
# Sample 4385:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6391891767492753
# Sample 4386:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5954496691606265
# Sample 4387:
#    Predicted: VASC, Actual: DF
#    Uncertainty: 0.5842166594081163
# Sample 4388:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.7356136119226804
# Sample 4389:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.9259156709560064
# Sample 4390:
#    Predicted: NV, Actual: BCC
#    Uncertainty: 0.575858404865217
# Sample 4391:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.49792256849877536
# Sample 4416:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.4097308329974755
# Sample 4417:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.19702316208235804
# Sample 4418:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.9422320517112677
# Sample 4419:
#    Predicted: NV, Actual: DF
#    Uncertainty: 0.9586053076714045
# Sample 4420:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7767584994324522
# Sample 4421:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 0.08980577875245144
# Sample 4422:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.06541718115284434
# Sample 4423:
#    Predicted: VASC, Actual: AK
#    Uncertainty: 0.5994098592753837
# Sample 4448:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.8107004948620727
# Sample 4449:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.27670491864272884
# Sample 4450:
#    Predicted: AK, Actual: BKL
#    Uncertainty: 0.6108980333435722
# Sample 4451:
#    Predicted: VASC, Actual: BKL
#    Uncertainty: 0.07708494817304035
# Sample 4452:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.6521151417668734
# Sample 4453:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2578489979702291
# Sample 4454:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.044170304705944186
# Sample 4455:
#    Predicted: NV, Actual: DF
#    Uncertainty: 0.05472393030292766
# Sample 4480:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.8601932193520775
# Sample 4481:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.8176939161980507
# Sample 4482:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.5557138893288259
# Sample 4483:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.49784062198994905
# Sample 4484:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7944408677718094
# Sample 4485:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.44808779255771214
# Sample 4486:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5955152995020765
# Sample 4487:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8888414832802659
# Sample 4512:
#    Predicted: BCC, Actual: BKL
#    Uncertainty: 0.1384166205473829
# Sample 4513:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.6884715491724934
# Sample 4514:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.42502443006152235
# Sample 4515:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.9646789269851205
# Sample 4516:
#    Predicted: VASC, Actual: AK
#    Uncertainty: 0.0037291784953111806
# Sample 4517:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.7523300357000404
# Sample 4518:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.8529370904331588
# Sample 4519:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.2970476180819137
# Sample 4544:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.5074170674664982
# Sample 4545:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8718675334742824
# Sample 4546:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.6161952625334163
# Sample 4547:
#    Predicted: BCC, Actual: SCC
#    Uncertainty: 0.8934534137702285
# Sample 4548:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.07966204958410616
# Sample 4549:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7936845723732376
# Sample 4550:
#    Predicted: BKL, Actual: SCC
#    Uncertainty: 0.8042392409645294
# Sample 4551:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.25359580610985144
# Sample 4576:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.12209196106736542
# Sample 4577:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.770183132777473
# Sample 4578:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.8447058944703588
# Sample 4579:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.3360647015171354
# Sample 4580:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.29893730336813884
# Sample 4581:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.07688352761185346
# Sample 4582:
#    Predicted: BKL, Actual: AK
#    Uncertainty: 0.045493232056758925
# Sample 4583:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5002851798711287
# Sample 4608:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 0.5917306887324759
# Sample 4609:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4055755474306707
# Sample 4610:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.634739759297518
# Sample 4611:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.44964040776466396
# Sample 4612:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8180794644274524
# Sample 4613:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.5541156120153417
# Sample 4614:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.27308278378731365
# Sample 4615:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6155047390620032
# Sample 4640:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.3789770520358735
# Sample 4641:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7941068203819504
# Sample 4642:
#    Predicted: BKL, Actual: MEL
#    Uncertainty: 0.039726663364625825
# Sample 4643:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.12756012715875842
# Sample 4644:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.2373438332559289
# Sample 4645:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.1250003688332395
# Sample 4646:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.6894062049003139
# Sample 4647:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.7286649234886526
# Sample 4672:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.12012208913743205
# Sample 4673:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.4010587672469702
# Sample 4674:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.544970561955238
# Sample 4675:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.7277771747920742
# Sample 4676:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.9871067720638579
# Sample 4677:
#    Predicted: BCC, Actual: BKL
#    Uncertainty: 0.4580320841348693
# Sample 4678:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.9344944845870866
# Sample 4679:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.5605926860228441
# Sample 4704:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.5221764970634316
# Sample 4705:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5029711279035256
# Sample 4706:
#    Predicted: BCC, Actual: BKL
#    Uncertainty: 0.20900921370069903
# Sample 4707:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5394972327019595
# Sample 4708:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.6140311450535746
# Sample 4709:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.3256399033428825
# Sample 4710:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.08780907095178703
# Sample 4711:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7907312012049681
# Sample 4736:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.4220908697900251
# Sample 4737:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.7958349375726678
# Sample 4738:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6440566395553058
# Sample 4739:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.34848694214756104
# Sample 4740:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.5710916464497988
# Sample 4741:
#    Predicted: BCC, Actual: BKL
#    Uncertainty: 0.4713970612238958
# Sample 4742:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.49324806045159275
# Sample 4743:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.9759164621320873
# Sample 4768:
#    Predicted: MEL, Actual: BCC
#    Uncertainty: 0.013426327637756641
# Sample 4769:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.9520036886428338
# Sample 4770:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.034806986267496454
# Sample 4771:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6497799467966222
# Sample 4772:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.6304304308693874
# Sample 4773:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.6000244378247443
# Sample 4774:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.3219480752066066
# Sample 4775:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4792274653533912
# Sample 4800:
#    Predicted: BKL, Actual: NV
#    Uncertainty: 0.7354459182103387
# Sample 4801:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.833178362251343
# Sample 4802:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.19714185723652122
# Sample 4803:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2794295787651476
# Sample 4804:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.258651832542077
# Sample 4805:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.29791891611094057
# Sample 4806:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.0658255919961731
# Sample 4807:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8593317304231286
# Sample 4832:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.2780234724275773
# Sample 4833:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.21923731099537636
# Sample 4834:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8623924720810068
# Sample 4835:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.3789540604324062
# Sample 4836:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2978375880951242
# Sample 4837:
#    Predicted: BCC, Actual: DF
#    Uncertainty: 0.23340449187061418
# Sample 4838:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.20723879968636794
# Sample 4839:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.131697255653068
# Sample 4864:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.8794163361477284
# Sample 4865:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.2651050150578348
# Sample 4866:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.5149915940115108
# Sample 4867:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.6408990220111026
# Sample 4868:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.8835462293566892
# Sample 4869:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7568801433869949
# Sample 4870:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7790561522740015
# Sample 4871:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.3046967827715855
# Sample 4896:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.5553329272981542
# Sample 4897:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.4420767484151519
# Sample 4898:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.5387902603111078
# Sample 4899:
#    Predicted: BKL, Actual: BKL
#    Uncertainty: 0.8037685919731983
# Sample 4900:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8854178837822195
# Sample 4901:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.9688956637868644
# Sample 4902:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6255151940480824
# Sample 4903:
#    Predicted: BCC, Actual: AK
#    Uncertainty: 0.9942235545080175
# Sample 4928:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.11685457165503343
# Sample 4929:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.09264919049263387
# Sample 4930:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6106029645191275
# Sample 4931:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6064834756860701
# Sample 4932:
#    Predicted: MEL, Actual: NV
#    Uncertainty: 0.395421673352616
# Sample 4933:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.5946032411200539
# Sample 4934:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.34549743303783953
# Sample 4935:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.955348002345264
# Sample 4960:
#    Predicted: BCC, Actual: NV
#    Uncertainty: 0.5601522547059548
# Sample 4961:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6457150116486577
# Sample 4962:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.6899309948647594
# Sample 4963:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.23019536017282383
# Sample 4964:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7641173083795882
# Sample 4965:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.4534021983118832
# Sample 4966:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.01683989557072474
# Sample 4967:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.8733174653437675
# Sample 4992:
#    Predicted: NV, Actual: AK
#    Uncertainty: 0.260748567258938
# Sample 4993:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.7303711729651531
# Sample 4994:
#    Predicted: MEL, Actual: MEL
#    Uncertainty: 0.13285207673762112
# Sample 4995:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8852361783981381
# Sample 4996:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.16509651724742813
# Sample 4997:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.4763045807754025
# Sample 4998:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.2945059262886486
# Sample 4999:
#    Predicted: VASC, Actual: AK
#    Uncertainty: 0.5197012434518548
# Sample 5024:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.36255318121446745
# Sample 5025:
#    Predicted: NV, Actual: BKL
#    Uncertainty: 0.5310291610530999
# Sample 5026:
#    Predicted: NV, Actual: MEL
#    Uncertainty: 0.24153532680014034
# Sample 5027:
#    Predicted: VASC, Actual: VASC
#    Uncertainty: 0.9949603644485967
# Sample 5028:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.6826171870062998
# Sample 5029:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.7750190982777625
# Sample 5030:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.09597646765168844
# Sample 5031:
#    Predicted: NV, Actual: NV
#    Uncertainty: 0.8646072529727163
# Sample 5056:
#    Predicted: VASC, Actual: MEL
#    Uncertainty: 0.1392767744062322
# Sample 5057:
#    Predicted: VASC, Actual: BCC
#    Uncertainty: 0.37982461318637717
# Sample 5058:
#    Predicted: BCC, Actual: MEL
#    Uncertainty: 0.0590008629421368
# Sample 5059:
#    Predicted: VASC, Actual: DF
#    Uncertainty: 0.3161160050651667
# Sample 5060:
#    Predicted: VASC, Actual: BKL
#    Uncertainty: 0.7781279641550805
# Sample 5061:
#    Predicted: VASC, Actual: NV
#    Uncertainty: 0.32819495378716246
# Sample 5062:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.3294800641207406
# Sample 5063:
#    Predicted: BCC, Actual: BCC
#    Uncertainty: 0.27391070505023707

# %% [markdown]
# plot the results

# %%
# Interpolate the data for smoother curves
x_values = np.arange(len(random_risks))
total_steps = len(x_values)

# Convert x-values to percentage
x_smooth_percentage = (x_values / total_steps) * 100

# Create a smooth range for the x-axis
x_smooth_percentage_interp = np.linspace(x_smooth_percentage.min(), x_smooth_percentage.max(), 300)

# Interpolate the data based on the percentage values
random_risks_smooth = np.interp(x_smooth_percentage_interp, x_smooth_percentage, random_risks)
softmax_risks_smooth = np.interp(x_smooth_percentage_interp, x_smooth_percentage, softmax_risks)
mc_dropout_risks_smooth = np.interp(x_smooth_percentage_interp, x_smooth_percentage, mc_dropout_risks)

# Plotting the results with smooth curves
plt.plot(x_smooth_percentage_interp, random_risks_smooth, label='Random Risks', linewidth=1)
plt.plot(x_smooth_percentage_interp, softmax_risks_smooth, label='Softmax Risks', linewidth=1)
plt.plot(x_smooth_percentage_interp, mc_dropout_risks_smooth, label='MC Dropout Risks', linewidth=1)

# x-axis label with a percentage
plt.xlabel('Coverage (%)')
plt.ylabel('Risk')
plt.title('Risk vs. Coverage')

# Adjust the y-axis limits
plt.ylim(0, 1)

# Invert the x-axis
plt.gca().invert_xaxis()

# Show legend
plt.legend()

plt.show()
